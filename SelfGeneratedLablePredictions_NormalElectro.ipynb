# %% [markdown]
# # Binary Classification: Normal vs Electrolarynx

# %% [raw]
# This file contains funtions and code that are used to design a simple DNN to help predict lables from the given audio clips. For reference, this audio used in this is from the rainbow passage speech. Each file is labeled as electrolarynx or normal. The goal is to see whether or not the seperate files would be classified. The code is based on this repo: https://github.com/markadivalerio/audio-classifier-project/blob/master/audio-classifier-project.ipynb
#
# Instead of using the function defined in the github repo for the confusion matrix, we used this code to get a sense of the true positives, true negatives, false positives, and false negatives.
# Website: https://www.stackvidhya.com/plot-confusion-matrix-in-python-and why/#:~:text=You%20can%20create%20the%20confusion,False%20Negatives%2C%20and%20True%20negatives.

# %% [markdown]
# ## Installing needed modules

# %%
import warnings
warnings.filterwarnings("ignore")

import re
import os
import random
from datetime import datetime

import librosa
from scipy.io import wavfile
import numpy as np
import pandas as pd
import sklearn as sk
import tensorflow as tf
import keras
from keras.callbacks import ModelCheckpoint 
from keras.models import Sequential, model_from_json
from keras.layers import Dense
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from sklearn import model_selection
from sklearn.metrics import confusion_matrix

import IPython.display as ipd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
### Training / Fitting / Optimizing Model #####
test_size = 0.2
epochs    = 50
batch_size= 40
#Justification for optimizer chosen: https://www.analyticsvidhya.com/blog/2021/10/a-comprehensive-guide-on-deep-learning-optimizers/ 
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)
#optimizer = SGD(learning_rate=0.001,momentum =0.9)

# %% [markdown]
# ## Helper Functions

# %%
def extract_features(file_name):
    """
    Extracts 193 chromatographic features from sound file. 
    including: MFCC's, Chroma_StFt, Melspectrogram, Spectral Contrast, and Tonnetz
    NOTE: this extraction technique changes the time series nature of the data
    """
    features = []
    
    audio_data, sample_rate = librosa.load(file_name)
    #stft = np.abs(librosa.stft(audio_data))
    
    mfcc = np.mean(librosa.feature.mfcc(y=audio_data, sr=sample_rate, n_mfcc=40).T,axis=0)
    features.extend(mfcc) # 40 = 40
    
    #chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
    #features.extend(chroma) # 12 = 52
    
    mel = np.mean(librosa.feature.melspectrogram(audio_data, sr=sample_rate).T,axis=0)
    features.extend(mel) # 128 = 180
    
    #contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0)
    #features.extend(contrast) # 7 = 187

# More possible features to add
#     tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X, ), sr=sample_rate).T,axis=0)
#     spec_cent = np.mean(librosa.feature.spectral_centroid(y=audio_data, sr=sample_rate).T, axis=0)
#     spec_bw = np.mean(librosa.feature.spectral_bandwidth(y=audio_data, sr=sample_rate).T, axis=0)
#     rolloff = np.mean(librosa.feature.spectral_rolloff(y=audio_data, sr=sample_rate).T, axis=0)
#     zcr = np.mean(librosa.feature.zero_crossing_rate(audio_data).T, axis=0)
#     features.extend(tonnetz) # 6 = 193
#     features.extend(spec_cent)
#     features.extend(spec_bw)
#     features.extend(rolloff)
#     features.extend(zcr)

    return np.array(features)

# %%
def display_wav(file = None):
    # Displays comparison of loading a wav file via librosa vs via scipy
    if not file:
        print("No wav file to display")
        return
    librosa_load, librosa_sampling_rate = librosa.load(file)
    scipy_sampling_rate, scipy_load = wavfile.read(file)
    print('original sample rate:',scipy_sampling_rate)
    print('converted sample rate:',librosa_sampling_rate)
    print('\n')
    print('original wav file min~max range:',np.min(scipy_load),'~',np.max(scipy_load))
    print('converted wav file min~max range:',np.min(librosa_load),'~',np.max(librosa_load))
    plt.figure(figsize=(12, 4))
    plt.plot(scipy_load)
    plt.figure(figsize=(12, 4))
    plt.plot(librosa_load)

# %%
def load_all_wav_files(files):
    '''
    Returns two numpy array
    The first is a numpy array containing each audio's numerical features - see extract_features()
    The second numpy array is the array *STRING* of the label.
    (The array indexes align up between the two arrays. data[idx] is classified as labels[idx]) 
    '''
    one_file = None
    #THIS WILL TAKE A WHILE!!!!!
    all_data = []
    all_labels = []
#SHORTCUT
# This is in here for quick tests - only loads first Ultrasound8k folder (instead of all of them)
#             if len(all_data) > 0: 
#                 break
#END SHORTCUT
    for idx, file in enumerate(files):
        if file.find('Normal')!=-1:
            features = extract_features(file)
            label = "normal"
            all_data.append(features)
            all_labels.append(label)
#                     display_wav(fname)
#                     break
        if file.find('Electrolarynx')!=1:
            features = extract_features(file)
            label = "electrolarynx"
            all_data.append(features)
            all_labels.append(label)
    return np.array(all_data), np.array(all_labels)

# %%
def analyze_features(all_data, all_labels):
    #seeking only the numeric features from the data
    numeric_features = all_data.select_dtypes(include = [np.number])
    print(numeric_features.dtypes)
    corr = numeric_features.corr()
    print(corr)
#     print(corr['SalePrice'].sort_values(ascending = False)[:5], '\n')
#     print(corr['SalePrice'].sort_values(ascending = False)[-5:])

# %%
def plot_history(history = None):
    # Plots accuracy & loss versus epochs
    if not history:
        print("No history to plot")
        return
    fig = plt.figure(figsize=(10,8))
#     fig = plt.figure(figsize=(20,16))
    plt.plot(history.history['loss'], label="Loss")
    plt.plot(history.history['accuracy'], label="Accuracy")
    plt.axis([0,90,0,1.1])
    plt.title("Accuracy and Loss vs Epoch")
    plt.xlabel("Epoch")
    plt.ylabel("Percentage")
    plt.legend()
    plt.show()

# %% [markdown]
# ## Creating the Data

# %%
#creating the list of filenames
import glob
#change the file path to where you have stored the normal_larynx files
DATA_DIR = glob.glob('/scratch/sg2dk/Capstone_Part2/*/Normal/*_transcribed.wav')
normalFiles=[]
# Shuffle

for flist in DATA_DIR:
    normalFiles.append(flist)
    ipd.Audio(flist)
print(normalFiles)
# Out:
# ['/scratch/sg2dk/Capstone_Part2/Participant1/Normal/20.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant1/Normal/15.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant1/Normal/23.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant1/Normal/18.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant1/Normal/16.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant1/Normal/14.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant1/Normal/13.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant1/Normal/21.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant1/Normal/17.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant1/Normal/19.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant1/Normal/22.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant5/Normal/98.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant5/Normal/96.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant5/Normal/100.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant5/Normal/95.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant5/Normal/103.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant5/Normal/97.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant5/Normal/101.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant5/Normal/99.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant5/Normal/94.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant5/Normal/102.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant2/Normal/37.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant2/Normal/39.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant2/Normal/44.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant2/Normal/43.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant2/Normal/40.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant2/Normal/42.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant2/Normal/38.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant2/Normal/36.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant2/Normal/41.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant3/Normal/57.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant3/Normal/59.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant3/Normal/62.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant3/Normal/61.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant3/Normal/64.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant3/Normal/63.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant3/Normal/58.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant3/Normal/56.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant3/Normal/60.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant3/Normal/55.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant4/Normal/74.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant4/Normal/82.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant4/Normal/81.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant4/Normal/79.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant4/Normal/77.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant4/Normal/83.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant4/Normal/75.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant4/Normal/76.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant4/Normal/78.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant4/Normal/80.mp4_transcribed.wav']

# %%
#change the file path in data dir to where your electrolaynx files are stored 
DATA_DIR = glob.glob('/scratch/sg2dk/Capstone_Part2/*/Electrolarynx/*_transcribed.wav')
filenames=[]
# Shuffle

for flist in DATA_DIR:
    filenames.append(flist)
print(filenames)
# Out:
# ['/scratch/sg2dk/Capstone_Part2/Participant1/Electrolarynx/12.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant1/Electrolarynx/6.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant1/Electrolarynx/8.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant1/Electrolarynx/11.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant1/Electrolarynx/5.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant1/Electrolarynx/2.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant1/Electrolarynx/9.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant1/Electrolarynx/7.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant1/Electrolarynx/3.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant1/Electrolarynx/4.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant1/Electrolarynx/10.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant5/Electrolarynx/85.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant5/Electrolarynx/91.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant5/Electrolarynx/92.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant5/Electrolarynx/88.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant5/Electrolarynx/86.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant5/Electrolarynx/90.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant5/Electrolarynx/84.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant5/Electrolarynx/87.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant5/Electrolarynx/89.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant5/Electrolarynx/93.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/24.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/30.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/33.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/34.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/29.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/27.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/31.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/25.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/26.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/28.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/35.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/32.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant3/Electrolarynx/48.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant3/Electrolarynx/52.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant3/Electrolarynx/46.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant3/Electrolarynx/45.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant3/Electrolarynx/51.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant3/Electrolarynx/47.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant3/Electrolarynx/53.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant3/Electrolarynx/49.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant3/Electrolarynx/54.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant3/Electrolarynx/50.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant4/Electrolarynx/70.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant4/Electrolarynx/67.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant4/Electrolarynx/69.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant4/Electrolarynx/73.mp4_transcribed.wav', '/scratch/sg2dk/Capstone_Part2/Participant4/Electrolarynx/65.mp4_transcribed.wav', '/scratch/sg2dk/Capston ...

# %%
#combining all the files into one list
allFiles = np.concatenate([filenames,normalFiles])
print(allFiles)
# Out:
# ['/scratch/sg2dk/Capstone_Part2/Participant1/Electrolarynx/12.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant1/Electrolarynx/6.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant1/Electrolarynx/8.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant1/Electrolarynx/11.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant1/Electrolarynx/5.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant1/Electrolarynx/2.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant1/Electrolarynx/9.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant1/Electrolarynx/7.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant1/Electrolarynx/3.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant1/Electrolarynx/4.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant1/Electrolarynx/10.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant5/Electrolarynx/85.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant5/Electrolarynx/91.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant5/Electrolarynx/92.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant5/Electrolarynx/88.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant5/Electrolarynx/86.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant5/Electrolarynx/90.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant5/Electrolarynx/84.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant5/Electrolarynx/87.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant5/Electrolarynx/89.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant5/Electrolarynx/93.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/24.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/30.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/33.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/34.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/29.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/27.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/31.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/25.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/26.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/28.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/35.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant2/Electrolarynx/32.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant3/Electrolarynx/48.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant3/Electrolarynx/52.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant3/Electrolarynx/46.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant3/Electrolarynx/45.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant3/Electrolarynx/51.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant3/Electrolarynx/47.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant3/Electrolarynx/53.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant3/Electrolarynx/49.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant3/Electrolarynx/54.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant3/Electrolarynx/50.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant4/Electrolarynx/70.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant4/Electrolarynx/67.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant4/Electrolarynx/69.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant4/Electrolarynx/73.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant4/Electrolarynx/65.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant4/Electrolarynx/71.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant4/Electrolarynx/72.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant4/Electrolarynx/68.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant4/Electrolarynx/66.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant1/Normal/20.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant1/Normal/15.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant1/Normal/23.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant1/Normal/18.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant1/Normal/16.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant1/Normal/14.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant1/Normal/13.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant1/Normal/21.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant1/Normal/17.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant1/Normal/19.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant1/Normal/22.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant5/Normal/98.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant5/Normal/96.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant5/Normal/100.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant5/Normal/95.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant5/Normal/103.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant5/Normal/97.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant5/Normal/101.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant5/Normal/99.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant5/Normal/94.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant5/Normal/102.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant2/Normal/37.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant2/Normal/39.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant2/Normal/44.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant2/Normal/43.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant2/Normal/40.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant2/Normal/42.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant2/Normal/38.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant2/Normal/36.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant2/Normal/41.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant3/Normal/57.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant3/Normal/59.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant3/Normal/62.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant3/Normal/61.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant3/Normal/64.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant3/Normal/63.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant3/Normal/58.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant3/Normal/56.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant3/Normal/60.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant3/Normal/55.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant4/Normal/74.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant4/Normal/82.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant4/Normal/81.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant4/Normal/79.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant4/Normal/77.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant4/Normal/83.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant4/Normal/75.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant4/Normal/76.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant4/Normal/78.mp4_transcribed.wav'
#  '/scratch/sg2dk/Capstone_Part2/Participant4/Normal/80.mp4_transcribed.wav']

# %% [markdown]
# ## Starting to Create the Model

# %%
all_data = np.array([])
all_labels_list = []
all_labels = np.array([])
one_file = None

all_data, all_labels= load_all_wav_files(allFiles)

# %%
print(all_data.shape)
classes = list(set(all_labels)) # classes = unique list of labels
n_classes = len(classes)
numeric_labels = np.array([classes.index(label) for label in all_labels]) # labels by index
print(classes)
# Out:
# (152, 168)
# ['electrolarynx', 'normal']

# %%
x_train, x_test, y_train, y_test = sk.model_selection.train_test_split(all_data, numeric_labels, test_size=test_size,random_state=0, shuffle=True)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (121, 168)
# (121,)
# (31, 168)
# (31,)

# %%
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization, LSTM
from keras.layers import Conv2D, MaxPooling2D
from keras import regularizers, optimizers
from keras import layers
from keras import models
from keras.layers.advanced_activations import LeakyReLU


#Trying to do a binary classification:https://www.pluralsight.com/guides/deep-learning-model-perform-binary-classification
model = keras.Sequential([
    keras.layers.Dense(64, activation='relu',input_shape=(x_train.shape[1],)),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])



model.compile(optimizer=optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])
#Plot summary
model.summary()

history = model.fit(x_train, y_train,
                    epochs=epochs,
                    batch_size=batch_size,
                    validation_data=(x_test, y_test),
#                         shuffle=True,
                    verbose=2)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                10816
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 12,929
# Trainable params: 12,929
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 4/4 - 0s - loss: 2.9592 - accuracy: 0.4463 - val_loss: 1.2598 - val_accuracy: 0.7419
# Epoch 2/50
# 4/4 - 0s - loss: 1.8729 - accuracy: 0.6446 - val_loss: 1.1985 - val_accuracy: 0.6129
# Epoch 3/50
# 4/4 - 0s - loss: 0.9368 - accuracy: 0.6942 - val_loss: 2.7769 - val_accuracy: 0.5806
# Epoch 4/50
# 4/4 - 0s - loss: 1.7227 - accuracy: 0.6529 - val_loss: 1.6506 - val_accuracy: 0.5806
# Epoch 5/50
# 4/4 - 0s - loss: 0.7378 - accuracy: 0.7190 - val_loss: 0.7409 - val_accuracy: 0.6774
# Epoch 6/50
# 4/4 - 0s - loss: 1.2433 - accuracy: 0.6612 - val_loss: 0.7681 - val_accuracy: 0.7419
# Epoch 7/50
# 4/4 - 0s - loss: 0.9808 - accuracy: 0.6612 - val_loss: 1.1628 - val_accuracy: 0.6129
# Epoch 8/50
# 4/4 - 0s - loss: 0.6485 - accuracy: 0.6860 - val_loss: 1.6136 - val_accuracy: 0.6129
# Epoch 9/50
# 4/4 - 0s - loss: 0.7669 - accuracy: 0.6777 - val_loss: 1.0170 - val_accuracy: 0.5806
# Epoch 10/50
# 4/4 - 0s - loss: 0.5207 - accuracy: 0.6942 - val_loss: 0.7932 - val_accuracy: 0.5806
# Epoch 11/50
# 4/4 - 0s - loss: 0.5667 - accuracy: 0.6942 - val_loss: 0.8084 - val_accuracy: 0.5806
# Epoch 12/50
# 4/4 - 0s - loss: 0.4968 - accuracy: 0.7025 - val_loss: 1.1840 - val_accuracy: 0.5806
# Epoch 13/50
# 4/4 - 0s - loss: 0.7213 - accuracy: 0.6694 - val_loss: 1.1895 - val_accuracy: 0.5484
# Epoch 14/50
# 4/4 - 0s - loss: 0.6897 - accuracy: 0.7190 - val_loss: 0.7930 - val_accuracy: 0.7419
# Epoch 15/50
# 4/4 - 0s - loss: 1.5714 - accuracy: 0.6529 - val_loss: 0.8237 - val_accuracy: 0.7419
# Epoch 16/50
# 4/4 - 0s - loss: 1.5947 - accuracy: 0.6446 - val_loss: 0.7744 - val_accuracy: 0.6774
# Epoch 17/50
# 4/4 - 0s - loss: 1.0451 - accuracy: 0.6694 - val_loss: 1.1842 - val_accuracy: 0.6774
# Epoch 18/50
# 4/4 - 0s - loss: 0.8245 - accuracy: 0.6777 - val_loss: 1.6744 - val_accuracy: 0.6129
# Epoch 19/50
# 4/4 - 0s - loss: 1.0087 - accuracy: 0.6942 - val_loss: 1.0742 - val_accuracy: 0.6129
# Epoch 20/50
# 4/4 - 0s - loss: 0.7309 - accuracy: 0.6694 - val_loss: 0.8410 - val_accuracy: 0.7097
# Epoch 21/50
# 4/4 - 0s - loss: 0.8286 - accuracy: 0.6529 - val_loss: 0.8373 - val_accuracy: 0.7097
# Epoch 22/50
# 4/4 - 0s - loss: 0.7695 - accuracy: 0.6612 - val_loss: 1.6398 - val_accuracy: 0.5806
# Epoch 23/50
# 4/4 - 0s - loss: 1.2559 - accuracy: 0.6942 - val_loss: 1.3824 - val_accuracy: 0.6452
# Epoch 24/50
# 4/4 - 0s - loss: 0.9628 - accuracy: 0.6777 - val_loss: 1.0425 - val_accuracy: 0.6774
# Epoch 25/50
# 4/4 - 0s - loss: 1.5159 - accuracy: 0.6694 - val_loss: 1.4927 - val_accuracy: 0.7419
# Epoch 26/50
# 4/4 - 0s - loss: 2.2346 - accuracy: 0.6529 - val_loss: 1.2143 - val_accuracy: 0.6452
# Epoch 27/50
# 4/4 - 0s - loss: 1.8390 - accuracy: 0.6529 - val_loss: 1.1091 - val_accuracy: 0.6774
# Epoch 28/50
# 4/4 - 0s - loss: 0.9126 - accuracy: 0.6612 - val_loss: 2.3407 - val_accuracy: 0.6129
# Epoch 29/50
# 4/4 - 0s - loss: 1.6727 - accuracy: 0.6777 - val_loss: 2.1935 - val_accuracy: 0.6129
# Epoch 30/50
# 4/4 - 0s - loss: 1.2782 - accuracy: 0.7025 - val_loss: 1.0529 - val_accuracy: 0.7097
# Epoch 31/50
# 4/4 - 0s - loss: 1.0600 - accuracy: 0.6612 - val_loss: 1.2293 - val_accuracy: 0.6452
# Epoch 32/50
# 4/4 - 0s - loss: 1.3679 - accuracy: 0.6694 - val_loss: 1.3219 - val_accuracy: 0.7097
# Epoch 33/50
# 4/4 - 0s - loss: 1.3871 - accuracy: 0.6612 - val_loss: 1.0808 - val_accuracy: 0.6774
# Epoch 34/50
# 4/4 - 0s - loss: 0.9581 - accuracy: 0.6860 - val_loss: 1.1371 - val_accuracy: 0.6452
# Epoch 35/50
# 4/4 - 0s - loss: 0.9084 - accuracy: 0.6777 - val_loss: 0.9287 - val_accuracy: 0.6774
# Epoch 36/50
# 4/4 - 0s - loss: 1.1739 - accuracy: 0.6694 - val_loss: 0.7988 - val_accuracy: 0.6774
# Epoch 37/50
# 4/4 - 0s - loss: 1.1485 - accuracy: 0.6694 - val_loss: 0.7525 - val_accuracy: 0.6129
# Epoch 38/50
# 4/4 - 0s - loss: 0.9888 - accuracy: 0.6942 - val_loss: 1.0199 - val_accuracy: 0.6129
# Epoch 39/50
# 4/4 - 0s - loss: 0.9036 - accuracy: 0.6364 - val_loss: 1.7202 - val_accuracy: 0.5806
# Epoch 40/50
# 4/4 - 0s - loss: 1.2925 - accuracy: 0.6777 - val_loss: 1.2492 - val_accuracy: 0.6129
# Epoch 41/50
# 4/4 - 0s - loss: 0.8864 - accuracy: 0.6860 - val_loss: 0.9166 - val_accuracy: 0.7097
# Epoch 42/50
# 4/4 - 0s - loss: 0.9663 - accuracy: 0.6446 - val_loss: 1.1776 - val_accuracy: 0.7097
# Epoch 43/50
# 4/4 - 0s - loss: 1.5000 - accuracy: 0.6529 - val_loss: 1.2838 - val_accuracy: 0.7419
# Epoch 44/50
# 4/4 - 0s - loss: 1.5028 - accuracy: 0.6529 - val_loss: 0.7028 - val_accuracy: 0.7097
# Epoch 45/50
# 4/4 - 0s - loss: 0.6836 - accuracy: 0.6860 - val_loss: 0.9818 - val_accuracy: 0.6129
# Epoch 46/50
# 4/4 - 0s - loss: 0.6494 - accuracy: 0.6942 - val_loss: 1.6235 - val_accuracy: 0.6129
# Epoch 47/50
# 4/4 - 0s - loss: 1.0359 - accuracy: 0.6860 - val_loss: 1.6172 - val_accuracy: 0.6129
# Epoch 48/50
# 4/4 - 0s - loss: 0.8043 - accuracy: 0.6860 - val_loss: 0.8983 - val_accuracy: 0.6452
# Epoch 49/50
# 4/4 - 0s - loss: 0.5963 - accuracy: 0.6694 - val_loss: 0.7483 - val_accuracy: 0.6452
# Epoch 50/50
# 4/4 - 0s - loss: 0.7233 - accuracy: 0.6694 - val_loss: 0.7306 - val_accuracy: 0.6129

# %%
score_train = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score_train[1])
print("Training Cross Entropy: %.2f" % score_train[0])

score_test = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score_test[1])
print("Testing Cross Entropy: %.2f" % score_test[0])
# Out:
# Training Accuracy:  0.6859503984451294
# Training Cross Entropy: 0.59
# Testing Accuracy:  0.6129032373428345
# Testing Cross Entropy: 0.73

# %% [markdown]
# ## Plotting the Results

# %%
y_pred_percentages = model.predict(x_test) # predicted percentages

y_pred = np.argmax(y_pred_percentages, axis=1) # Most prevalent prediction

#Plotting the confusion matrix:
import seaborn as sns

cm = confusion_matrix(y_test, y_pred)
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cm.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cm.flatten()/np.sum(cm)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)

ax = sns.heatmap(cm, annot=labels, fmt="", cmap='Blues')
ax.set_title('Normal vs Electrolarynx Confusion Matrix');
ax.set_xlabel('Predicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

## Display the visualization of the Confusion Matrix and save it as png
plt.savefig("ConfusionMatrixBinary.png")

# %%
plot_history(history)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Normal vs Electrolarynx Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.savefig("NormalElectroAccu.png")
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
#32, 32 lstm, w/ mel, chroma, zcr, mfcc, sp_centroid, sp_rolloff
#sgd 0.01
#***
